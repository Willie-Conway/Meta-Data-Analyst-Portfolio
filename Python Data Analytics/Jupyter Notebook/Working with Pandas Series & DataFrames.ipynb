# %%
import pandas as pd

# %%
df = pd.read_csv('csv/customers.csv')
df.head()
# Out:
#                                           CustomerID  gender  SeniorCitizen  \
# 0  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...  Female              0
# 1  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    Male              0
# 2  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...  Female              1
# 3  4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...  Female              1
# 4  4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...  Female              1
#
#   Partner Dependents  Tenure PhoneService MultipleLines InternetService  \
# 0      No         No      58          Yes           Yes              No
# 1     Yes        Yes      64          Yes            No             DSL
# 2      No        Yes      11          Yes           Yes              No
# 3     Yes        Yes       3          Yes           Yes             DSL
# 4      No        Yes      40           No           Yes              No
#
#   DeviceProtection PaperlessBilling              PaymentMethod TotalCharges
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'Tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'DeviceProtection', 'PaperlessBilling', 'PaymentMethod',
#        'TotalCharges'],
#       dtype='object')

# %% [markdown]
# ## Columns of DataFrame

# %%
df['CustomerID']
# Out:
# 0       5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1       6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2       d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3       4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4       4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
#                               ...
# 3822    71300a607803afff20dbf578af63c845836ef7495a4df1...
# 3823    08ff39839627d6e1619e05b005f41c51face303bfb6fcd...
# 3824    03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...
# 3825    32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...
# 3826    61f1658abb2793093fd8a1afabc600dad20001526baa94...
# Name: CustomerID, Length: 3827, dtype: object

# %%
df.CustomerID
# Out:
# 0       5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1       6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2       d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3       4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4       4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
#                               ...
# 3822    71300a607803afff20dbf578af63c845836ef7495a4df1...
# 3823    08ff39839627d6e1619e05b005f41c51face303bfb6fcd...
# 3824    03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...
# 3825    32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...
# 3826    61f1658abb2793093fd8a1afabc600dad20001526baa94...
# Name: CustomerID, Length: 3827, dtype: object

# %%
df.1_column
# Out:
#   Cell In[6], line 1
#     df.1_column
#         ^
# SyntaxError: invalid decimal literal

# %%
df['SeniorCitizen']
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 3822    0
# 3823    0
# 3824    1
# 3825    0
# 3826    1
# Name: SeniorCitizen, Length: 3827, dtype: int64

# %% [markdown]
# ## Series

# %%
customer_ids = df.CustomerID
type(customer_ids)
# Out:
# pandas.core.series.Series

# %%
customer_ids
# Out:
# 0       5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1       6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2       d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3       4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4       4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
#                               ...
# 3822    71300a607803afff20dbf578af63c845836ef7495a4df1...
# 3823    08ff39839627d6e1619e05b005f41c51face303bfb6fcd...
# 3824    03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...
# 3825    32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...
# 3826    61f1658abb2793093fd8a1afabc600dad20001526baa94...
# Name: CustomerID, Length: 3827, dtype: object

# %%
customer_ids[1]
# Out:
# '6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d49c01e52ddb7875b4b'

# %%
customer_ids[10]
# Out:
# '4a44dc15364204a80fe80e9039455cc1608281820fe2b24f1e5233ade6af1dd5'

# %%
customer_ids[5000]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 5000 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 customer_ids[5000]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
# ...

# %%
customer_ids[3:10]
# Out:
# 3    4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4    4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
# 5    ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...
# 6    e7f6c011776e8db7cd330b54174fd76f7d0216b612387a...
# 7    7902699be42c8a8e46fbbb4501726517e86b22c56a189f...
# 8    2c624232cdd221771294dfbb310aca000a0df6ac8b66b6...
# 9    19581e27de7ced00ff1ce50b2047e7a567c76b1cbaebab...
# Name: CustomerID, dtype: object

# %%
# Example: Series from a dictionary
population_dict = {
    'California': 38332521,
    'Texas': 26448193,
    'New York': 19651127,
    'Florida': 19552860,
    'Illinois': 12882135
}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population['California']
# Out:
# np.int64(38332521)

# %% [markdown]
# ## Working with DataFrame Rows & Columns

# %%
df['CustomerID'][10]
# Out:
# '4a44dc15364204a80fe80e9039455cc1608281820fe2b24f1e5233ade6af1dd5'

# %%
df.loc[10, 'CustomerID']
# Out:
# '4a44dc15364204a80fe80e9039455cc1608281820fe2b24f1e5233ade6af1dd5'

# %%
df.iloc[10, 1]
# Out:
# 'Female'

# %%
df.head(11)
# Out:
#                                            CustomerID  gender  SeniorCitizen  \
# 0   5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...  Female              0
# 1   6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    Male              0
# 2   d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...  Female              1
# 3   4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...  Female              1
# 4   4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...  Female              1
# 5   ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...    Male              1
# 6   e7f6c011776e8db7cd330b54174fd76f7d0216b612387a...  Female              1
# 7   7902699be42c8a8e46fbbb4501726517e86b22c56a189f...  Female              0
# 8   2c624232cdd221771294dfbb310aca000a0df6ac8b66b6...  Female              1
# 9   19581e27de7ced00ff1ce50b2047e7a567c76b1cbaebab...    Male              0
# 10  4a44dc15364204a80fe80e9039455cc1608281820fe2b2...  Female              1
#
# ...

# %%
df[['CustomerID', 'TotalCharges']]
# Out:
#                                              CustomerID TotalCharges
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...     $1585.25
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...      $720.22
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...      $646.74
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...     $1883.51
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...       $83.26
# ...                                                 ...          ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...     $1463.55
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...     $1474.69
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...      $435.95
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...     $1046.15
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...     $1411.88
#
# [3827 rows x 2 columns]

# %%
columns_of_interest = ['CustomerID', 'TotalCharges']
df[columns_of_interest]
# Out:
#                                              CustomerID TotalCharges
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...     $1585.25
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...      $720.22
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...      $646.74
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...     $1883.51
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...       $83.26
# ...                                                 ...          ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...     $1463.55
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...     $1474.69
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...      $435.95
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...     $1046.15
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...     $1411.88
#
# [3827 rows x 2 columns]

# %%
df[['CustomerID', 'TotalCharges']]
# Out:
#                                              CustomerID TotalCharges
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...     $1585.25
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...      $720.22
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...      $646.74
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...     $1883.51
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...       $83.26
# ...                                                 ...          ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...     $1463.55
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...     $1474.69
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...      $435.95
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...     $1046.15
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...     $1411.88
#
# [3827 rows x 2 columns]

# %%
df[['TotalCharges', 'CustomerID']]
# Out:
#      TotalCharges                                         CustomerID
# 0        $1585.25  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1         $720.22  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2         $646.74  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3        $1883.51  4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4          $83.26  4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
# ...           ...                                                ...
# 3822     $1463.55  71300a607803afff20dbf578af63c845836ef7495a4df1...
# 3823     $1474.69  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...
# 3824      $435.95  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...
# 3825     $1046.15  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...
# 3826     $1411.88  61f1658abb2793093fd8a1afabc600dad20001526baa94...
#
# [3827 rows x 2 columns]

# %%
df[['CustomerID', 'TotalCharges', 'CustomerID']]
# Out:
#                                              CustomerID TotalCharges  \
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...     $1585.25
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...      $720.22
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...      $646.74
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...     $1883.51
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...       $83.26
# ...                                                 ...          ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...     $1463.55
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...     $1474.69
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...      $435.95
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...     $1046.15
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...     $1411.88
#
#                                              CustomerID
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# ...

# %%
df.loc[:, ['CustomerID', 'TotalCharges']]
# Out:
#                                              CustomerID TotalCharges
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...     $1585.25
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...      $720.22
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...      $646.74
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...     $1883.51
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...       $83.26
# ...                                                 ...          ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...     $1463.55
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...     $1474.69
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...      $435.95
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...     $1046.15
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...     $1411.88
#
# [3827 rows x 2 columns]

# %%
df.loc[:, ['CustomerID']]
# Out:
#                                              CustomerID
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
# ...                                                 ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...
#
# [3827 rows x 1 columns]

# %%
df.loc[:, 'CustomerID']
# Out:
# 0       5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1       6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2       d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3       4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4       4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
#                               ...
# 3822    71300a607803afff20dbf578af63c845836ef7495a4df1...
# 3823    08ff39839627d6e1619e05b005f41c51face303bfb6fcd...
# 3824    03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...
# 3825    32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...
# 3826    61f1658abb2793093fd8a1afabc600dad20001526baa94...
# Name: CustomerID, Length: 3827, dtype: object

# %%
df.loc[5, :]
# Out:
# CustomerID          ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...
# gender                                                           Male
# SeniorCitizen                                                       1
# Partner                                                            No
# Dependents                                                         No
# Tenure                                                              6
# PhoneService                                                       No
# MultipleLines                                                      No
# InternetService                                           Fiber optic
# DeviceProtection                                                   No
# PaperlessBilling                                                  Yes
# PaymentMethod                                 Credit card (automatic)
# TotalCharges                                                 $1534.58
# Name: 5, dtype: object

# %%
df.loc[[5], :]
# Out:
#                                           CustomerID gender  SeniorCitizen  \
# 5  ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...   Male              1
#
#   Partner Dependents  Tenure PhoneService MultipleLines InternetService  \
# 5      No         No       6           No            No     Fiber optic
#
#   DeviceProtection PaperlessBilling            PaymentMethod TotalCharges
# 5               No              Yes  Credit card (automatic)     $1534.58

# %%
df.loc[5]
# Out:
# CustomerID          ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...
# gender                                                           Male
# SeniorCitizen                                                       1
# Partner                                                            No
# Dependents                                                         No
# Tenure                                                              6
# PhoneService                                                       No
# MultipleLines                                                      No
# InternetService                                           Fiber optic
# DeviceProtection                                                   No
# PaperlessBilling                                                  Yes
# PaymentMethod                                 Credit card (automatic)
# TotalCharges                                                 $1534.58
# Name: 5, dtype: object

# %%
df.loc[5, :]
# Out:
# CustomerID          ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...
# gender                                                           Male
# SeniorCitizen                                                       1
# Partner                                                            No
# Dependents                                                         No
# Tenure                                                              6
# PhoneService                                                       No
# MultipleLines                                                      No
# InternetService                                           Fiber optic
# DeviceProtection                                                   No
# PaperlessBilling                                                  Yes
# PaymentMethod                                 Credit card (automatic)
# TotalCharges                                                 $1534.58
# Name: 5, dtype: object

# %%
df.loc[[5], :]
# Out:
#                                           CustomerID gender  SeniorCitizen  \
# 5  ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...   Male              1
#
#   Partner Dependents  Tenure PhoneService MultipleLines InternetService  \
# 5      No         No       6           No            No     Fiber optic
#
#   DeviceProtection PaperlessBilling            PaymentMethod TotalCharges
# 5               No              Yes  Credit card (automatic)     $1534.58

# %%
df.loc[2:8, :]
# Out:
#                                           CustomerID  gender  SeniorCitizen  \
# 2  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...  Female              1
# 3  4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...  Female              1
# 4  4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...  Female              1
# 5  ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...    Male              1
# 6  e7f6c011776e8db7cd330b54174fd76f7d0216b612387a...  Female              1
# 7  7902699be42c8a8e46fbbb4501726517e86b22c56a189f...  Female              0
# 8  2c624232cdd221771294dfbb310aca000a0df6ac8b66b6...  Female              1
#
#   Partner Dependents  Tenure PhoneService MultipleLines InternetService  \
# 2      No        Yes      11          Yes           Yes              No
# 3     Yes        Yes       3          Yes           Yes             DSL
# 4      No        Yes      40           No           Yes              No
# ...

# %%
df.loc[5:, ['TotalCharges', 'CustomerID']]
# Out:
#      TotalCharges                                         CustomerID
# 5        $1534.58  ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...
# 6         $966.19  e7f6c011776e8db7cd330b54174fd76f7d0216b612387a...
# 7        $1888.93  7902699be42c8a8e46fbbb4501726517e86b22c56a189f...
# 8         $786.94  2c624232cdd221771294dfbb310aca000a0df6ac8b66b6...
# 9        $1416.08  19581e27de7ced00ff1ce50b2047e7a567c76b1cbaebab...
# ...           ...                                                ...
# 3822     $1463.55  71300a607803afff20dbf578af63c845836ef7495a4df1...
# 3823     $1474.69  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...
# 3824      $435.95  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...
# 3825     $1046.15  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...
# 3826     $1411.88  61f1658abb2793093fd8a1afabc600dad20001526baa94...
#
# [3822 rows x 2 columns]

# %%
df.loc[[1,2,3,5,8], ['TotalCharges']]
# Out:
#   TotalCharges
# 1      $720.22
# 2      $646.74
# 3     $1883.51
# 5     $1534.58
# 8      $786.94
