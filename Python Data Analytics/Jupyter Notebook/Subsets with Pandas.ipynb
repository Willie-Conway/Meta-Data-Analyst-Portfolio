# %%
import pandas as pd

# %%
df_example = pd.DataFrame(
    data={
        'col0': [1, 3, 3, 5, 1],
        'col1': [7, 2, 94, 37, 49],
        'col2': [2, 6, 6, -1, 10],
    }
)
df_example
# Out:
#    col0  col1  col2
# 0     1     7     2
# 1     3     2     6
# 2     3    94     6
# 3     5    37    -1
# 4     1    49    10

# %%
df_example.loc[:, 'col1']
# Out:
# 0     7
# 1     2
# 2    94
# 3    37
# 4    49
# Name: col1, dtype: int64

# %%
my_mask = pd.Series([True, False, True, True, False])
df_example.loc[my_mask, :]
# Out:
#    col0  col1  col2
# 0     1     7     2
# 2     3    94     6
# 3     5    37    -1

# %%
df_example.loc[my_mask]
# Out:
#    col0  col1  col2
# 0     1     7     2
# 2     3    94     6
# 3     5    37    -1

# %%
df_example[my_mask]
# Out:
#    col0  col1  col2
# 0     1     7     2
# 2     3    94     6
# 3     5    37    -1

# %%
df_example[-my_mask]
# Out:
#    col0  col1  col2
# 1     3     2     6
# 4     1    49    10

# %%
df_example.loc[-my_mask]
# Out:
#    col0  col1  col2
# 1     3     2     6
# 4     1    49    10

# %% [markdown]
# ## Masking on Real Data

# %%
df = pd.read_csv('csv/small_customers.csv')
df
# Out:
#                                            CustomerID  Age  gender  \
# 0   5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   56    Male
# 1   6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   69  Female
# 2   d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   46    Male
# 3   4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   32  Female
# 4   4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60  Female
# ..                                                ...  ...     ...
# 95  ad48ff99415b2f007dc35b7eb553fd1eb35ebfa2f2f308...   46  Female
# 96  7b1a278f5abe8e9da907fc9c29dfd432d60dc76e17b0fa...   35  Female
# 97  d6d824abba4afde81129c71dea75b8100e96338da5f416...   43    Male
# 98  29db0c6782dbd5000559ef4d9e953e300e2b479eed26d8...   61    Male
# 99  8c1f1046219ddd216a023f792356ddf127fce372a72ec9...   51  Female
#
#     SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 0               1      No        Yes      63           No           Yes
# 1               0      No         No      62          Yes            No
# 2               0      No        Yes      68          Yes           Yes
# 3               1      No         No      21          Yes           Yes
# 4               1     Yes        Yes      66          Yes           Yes
# ..            ...     ...        ...     ...          ...           ...
# 95              0      No        Yes      11           No            No
# 96              0     Yes        Yes      24          Yes           Yes
# 97              1      No        Yes      51           No           Yes
# 98              0      No         No      52           No           Yes
# 99              1     Yes        Yes      22           No           Yes
#
#    InternetService DeviceProtection PaperlessBilling  \
# 0      Fiber optic               No               No
# 1               No               No              Yes
# 2              DSL               No              Yes
# 3      Fiber optic              Yes              Yes
# 4               No               No              Yes
# ..             ...              ...              ...
# 95             DSL               No               No
# 96     Fiber optic              Yes               No
# 97             DSL               No               No
# 98     Fiber optic               No               No
# 99             DSL              Yes              Yes
#
#                 PaymentMethod  TotalCharges
# 0            Electronic check        118.64
# 1                Mailed check        110.47
# 2   Bank transfer (automatic)        103.28
# 3   Bank transfer (automatic)        102.50
# 4     Credit card (automatic)        117.99
# ..                        ...           ...
# 95               Mailed check        104.65
# 96    Credit card (automatic)        103.01
# 97    Credit card (automatic)        102.22
# 98  Bank transfer (automatic)        110.12
# 99           Electronic check        100.00
#
# [100 rows x 14 columns]

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
my_mask_paid_at_least_100 = df['TotalCharges'] >= 100
my_mask_paid_at_least_100
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: TotalCharges, Length: 100, dtype: bool

# %%
ages_of_paid_100 = df.loc[my_mask_paid_at_least_100].get('Age')
ages_of_paid_100
# Out:
# 0     56
# 1     69
# 2     46
# 3     32
# 4     60
#       ..
# 95    46
# 96    35
# 97    43
# 98    61
# 99    51
# Name: Age, Length: 96, dtype: int64

# %%
df.loc[my_mask_paid_at_least_100, 'Age']
# Out:
# 0     56
# 1     69
# 2     46
# 3     32
# 4     60
#       ..
# 95    46
# 96    35
# 97    43
# 98    61
# 99    51
# Name: Age, Length: 96, dtype: int64

# %%
df.loc[df['TotalCharges'] >= 100, 'Age']
# Out:
# 0     56
# 1     69
# 2     46
# 3     32
# 4     60
#       ..
# 95    46
# 96    35
# 97    43
# 98    61
# 99    51
# Name: Age, Length: 96, dtype: int64

# %%
mask_null = df['InternetService'].isna()
mask_null
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: InternetService, Length: 100, dtype: bool

# %%
df[mask_null]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Age, gender, SeniorCitizen, Partner, Dependents, Tenure, PhoneService, MultipleLines, InternetService, DeviceProtection, PaperlessBilling, PaymentMethod, TotalCharges]
# Index: []

# %%
my_mask_paid_at_least_100 = df['TotalCharges'] >= 100
my_mask_adult = df['Age'] >= 18

# %%
df[my_mask_paid_at_least_100 & my_mask_adult]
# Out:
#                                            CustomerID  Age  gender  \
# 0   5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   56    Male
# 1   6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   69  Female
# 2   d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   46    Male
# 3   4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   32  Female
# 4   4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60  Female
# ..                                                ...  ...     ...
# 95  ad48ff99415b2f007dc35b7eb553fd1eb35ebfa2f2f308...   46  Female
# 96  7b1a278f5abe8e9da907fc9c29dfd432d60dc76e17b0fa...   35  Female
# 97  d6d824abba4afde81129c71dea75b8100e96338da5f416...   43    Male
# 98  29db0c6782dbd5000559ef4d9e953e300e2b479eed26d8...   61    Male
# 99  8c1f1046219ddd216a023f792356ddf127fce372a72ec9...   51  Female
#
#     SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 0               1      No        Yes      63           No           Yes
# 1               0      No         No      62          Yes            No
# 2               0      No        Yes      68          Yes           Yes
# 3               1      No         No      21          Yes           Yes
# 4               1     Yes        Yes      66          Yes           Yes
# ..            ...     ...        ...     ...          ...           ...
# 95              0      No        Yes      11           No            No
# 96              0     Yes        Yes      24          Yes           Yes
# 97              1      No        Yes      51           No           Yes
# 98              0      No         No      52           No           Yes
# 99              1     Yes        Yes      22           No           Yes
#
#    InternetService DeviceProtection PaperlessBilling  \
# 0      Fiber optic               No               No
# 1               No               No              Yes
# 2              DSL               No              Yes
# 3      Fiber optic              Yes              Yes
# 4               No               No              Yes
# ..             ...              ...              ...
# 95             DSL               No               No
# 96     Fiber optic              Yes               No
# 97             DSL               No               No
# 98     Fiber optic               No               No
# 99             DSL              Yes              Yes
#
#                 PaymentMethod  TotalCharges
# 0            Electronic check        118.64
# 1                Mailed check        110.47
# 2   Bank transfer (automatic)        103.28
# 3   Bank transfer (automatic)        102.50
# 4     Credit card (automatic)        117.99
# ..                        ...           ...
# 95               Mailed check        104.65
# 96    Credit card (automatic)        103.01
# 97    Credit card (automatic)        102.22
# 98  Bank transfer (automatic)        110.12
# 99           Electronic check        100.00
#
# [96 rows x 14 columns]

# %%
df[(-my_mask_paid_at_least_100) & my_mask_adult]
# Out:
#                                            CustomerID  Age  gender  \
# 7   7902699be42c8a8e46fbbb4501726517e86b22c56a189f...   38    Male
# 10  4a44dc15364204a80fe80e9039455cc1608281820fe2b2...   36  Female
# 15  e629fa6598d732768f7c726b4b621285f9c3b85303900a...   70    Male
# 17  4523540f1504cd17100c4835e85b7eefd49911580f8eff...   57    Male
#
#     SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 7               1      No         No      50          Yes            No
# 10              1      No         No      68           No            No
# 15              0     Yes         No      47          Yes            No
# 17              1     Yes         No      32           No            No
#
#    InternetService DeviceProtection PaperlessBilling  \
# 7              DSL               No              Yes
# 10             DSL              Yes              Yes
# 15              No              Yes              Yes
# 17             DSL              Yes               No
#
#                 PaymentMethod  TotalCharges
# 7   Bank transfer (automatic)         90.29
# 10    Credit card (automatic)         80.02
# 15  Bank transfer (automatic)         78.00
# 17    Credit card (automatic)         65.85

# %%
df[my_mask_paid_at_least_100 | my_mask_adult]
# Out:
#                                            CustomerID  Age  gender  \
# 0   5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   56    Male
# 1   6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   69  Female
# 2   d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   46    Male
# 3   4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   32  Female
# 4   4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60  Female
# ..                                                ...  ...     ...
# 95  ad48ff99415b2f007dc35b7eb553fd1eb35ebfa2f2f308...   46  Female
# 96  7b1a278f5abe8e9da907fc9c29dfd432d60dc76e17b0fa...   35  Female
# 97  d6d824abba4afde81129c71dea75b8100e96338da5f416...   43    Male
# 98  29db0c6782dbd5000559ef4d9e953e300e2b479eed26d8...   61    Male
# 99  8c1f1046219ddd216a023f792356ddf127fce372a72ec9...   51  Female
#
#     SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 0               1      No        Yes      63           No           Yes
# 1               0      No         No      62          Yes            No
# 2               0      No        Yes      68          Yes           Yes
# 3               1      No         No      21          Yes           Yes
# 4               1     Yes        Yes      66          Yes           Yes
# ..            ...     ...        ...     ...          ...           ...
# 95              0      No        Yes      11           No            No
# 96              0     Yes        Yes      24          Yes           Yes
# 97              1      No        Yes      51           No           Yes
# 98              0      No         No      52           No           Yes
# 99              1     Yes        Yes      22           No           Yes
#
#    InternetService DeviceProtection PaperlessBilling  \
# 0      Fiber optic               No               No
# 1               No               No              Yes
# 2              DSL               No              Yes
# 3      Fiber optic              Yes              Yes
# 4               No               No              Yes
# ..             ...              ...              ...
# 95             DSL               No               No
# 96     Fiber optic              Yes               No
# 97             DSL               No               No
# 98     Fiber optic               No               No
# 99             DSL              Yes              Yes
#
#                 PaymentMethod  TotalCharges
# 0            Electronic check        118.64
# 1                Mailed check        110.47
# 2   Bank transfer (automatic)        103.28
# 3   Bank transfer (automatic)        102.50
# 4     Credit card (automatic)        117.99
# ..                        ...           ...
# 95               Mailed check        104.65
# 96    Credit card (automatic)        103.01
# 97    Credit card (automatic)        102.22
# 98  Bank transfer (automatic)        110.12
# 99           Electronic check        100.00
#
# [100 rows x 14 columns]

# %%
df[-(df['TotalCharges'] >= 100) | (df['Age'] >= 18)]
# Out:
#                                            CustomerID  Age  gender  \
# 0   5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   56    Male
# 1   6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   69  Female
# 2   d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   46    Male
# 3   4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   32  Female
# 4   4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60  Female
# ..                                                ...  ...     ...
# 95  ad48ff99415b2f007dc35b7eb553fd1eb35ebfa2f2f308...   46  Female
# 96  7b1a278f5abe8e9da907fc9c29dfd432d60dc76e17b0fa...   35  Female
# 97  d6d824abba4afde81129c71dea75b8100e96338da5f416...   43    Male
# 98  29db0c6782dbd5000559ef4d9e953e300e2b479eed26d8...   61    Male
# 99  8c1f1046219ddd216a023f792356ddf127fce372a72ec9...   51  Female
#
#     SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 0               1      No        Yes      63           No           Yes
# 1               0      No         No      62          Yes            No
# 2               0      No        Yes      68          Yes           Yes
# 3               1      No         No      21          Yes           Yes
# 4               1     Yes        Yes      66          Yes           Yes
# ..            ...     ...        ...     ...          ...           ...
# 95              0      No        Yes      11           No            No
# 96              0     Yes        Yes      24          Yes           Yes
# 97              1      No        Yes      51           No           Yes
# 98              0      No         No      52           No           Yes
# 99              1     Yes        Yes      22           No           Yes
#
#    InternetService DeviceProtection PaperlessBilling  \
# 0      Fiber optic               No               No
# 1               No               No              Yes
# 2              DSL               No              Yes
# 3      Fiber optic              Yes              Yes
# 4               No               No              Yes
# ..             ...              ...              ...
# 95             DSL               No               No
# 96     Fiber optic              Yes               No
# 97             DSL               No               No
# 98     Fiber optic               No               No
# 99             DSL              Yes              Yes
#
#                 PaymentMethod  TotalCharges
# 0            Electronic check        118.64
# 1                Mailed check        110.47
# 2   Bank transfer (automatic)        103.28
# 3   Bank transfer (automatic)        102.50
# 4     Credit card (automatic)        117.99
# ..                        ...           ...
# 95               Mailed check        104.65
# 96    Credit card (automatic)        103.01
# 97    Credit card (automatic)        102.22
# 98  Bank transfer (automatic)        110.12
# 99           Electronic check        100.00
#
# [100 rows x 14 columns]

# %%
mask_paid_1t_100_or_adult = (-my_mask_paid_at_least_100) | my_mask_adult
df[mask_paid_1t_100_or_adult]
# Out:
#                                            CustomerID  Age  gender  \
# 0   5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   56    Male
# 1   6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   69  Female
# 2   d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   46    Male
# 3   4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   32  Female
# 4   4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60  Female
# ..                                                ...  ...     ...
# 95  ad48ff99415b2f007dc35b7eb553fd1eb35ebfa2f2f308...   46  Female
# 96  7b1a278f5abe8e9da907fc9c29dfd432d60dc76e17b0fa...   35  Female
# 97  d6d824abba4afde81129c71dea75b8100e96338da5f416...   43    Male
# 98  29db0c6782dbd5000559ef4d9e953e300e2b479eed26d8...   61    Male
# 99  8c1f1046219ddd216a023f792356ddf127fce372a72ec9...   51  Female
#
#     SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 0               1      No        Yes      63           No           Yes
# 1               0      No         No      62          Yes            No
# 2               0      No        Yes      68          Yes           Yes
# 3               1      No         No      21          Yes           Yes
# 4               1     Yes        Yes      66          Yes           Yes
# ..            ...     ...        ...     ...          ...           ...
# 95              0      No        Yes      11           No            No
# 96              0     Yes        Yes      24          Yes           Yes
# 97              1      No        Yes      51           No           Yes
# 98              0      No         No      52           No           Yes
# 99              1     Yes        Yes      22           No           Yes
#
#    InternetService DeviceProtection PaperlessBilling  \
# 0      Fiber optic               No               No
# 1               No               No              Yes
# 2              DSL               No              Yes
# 3      Fiber optic              Yes              Yes
# 4               No               No              Yes
# ..             ...              ...              ...
# 95             DSL               No               No
# 96     Fiber optic              Yes               No
# 97             DSL               No               No
# 98     Fiber optic               No               No
# 99             DSL              Yes              Yes
#
#                 PaymentMethod  TotalCharges
# 0            Electronic check        118.64
# 1                Mailed check        110.47
# 2   Bank transfer (automatic)        103.28
# 3   Bank transfer (automatic)        102.50
# 4     Credit card (automatic)        117.99
# ..                        ...           ...
# 95               Mailed check        104.65
# 96    Credit card (automatic)        103.01
# 97    Credit card (automatic)        102.22
# 98  Bank transfer (automatic)        110.12
# 99           Electronic check        100.00
#
# [100 rows x 14 columns]
