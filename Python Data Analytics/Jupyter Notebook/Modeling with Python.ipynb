# %% [markdown]
# ## Modeling in Python

# %% [markdown]
# #### Scikit-learn

# %% [markdown]
# ![Scikit-learn Logo](Images/Scikit_learn_logo.jpg)

# %% [markdown]
# #### Regression Models

# %% [markdown]
# ![Regression_Models](Images/Regression_Models.png)

# %% [markdown]
# #### Classifcation Models

# %% [markdown]
# ![Classification_Models](Images/Classification_Models.png)

# %% [markdown]
# #### Clustering Models

# %% [markdown]
# ![Clustering_Models](Images/Clustering_Models.png)

# %% [markdown]
# #### Modeling in Python

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('csv/butler_customers.csv')

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_group                333 non-null    object
#  1   location                      333 non-null    object
#  2   n_days_member                 333 non-null    int64
#  3   n_avg_items_browsed_per_week  333 non-null    int64
#  4   amount_spent                  333 non-null    float64
#  5   device                        333 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 15.7+ KB
#   customer_group  location  n_days_member  n_avg_items_browsed_per_week  \
# 0        Group C     Rural            110                            21
# 1        Group A     Rural            189                            26
# 2        Group C     Urban            239                            30
# ...

# %%
sns.pairplot(df)

# %%
#from pocket_data_scentist import FriendlyModeler

#my_modeler = FriendlyModeler(data=df, data_description='butler')

# %% [markdown]
# ### Regression

# %%
# Test results

#predictions = my_modeler.regression()

# %%
#predictions

# %%
df.loc[[0]]
# Out:
#   customer_group location  n_days_member  n_avg_items_browsed_per_week  \
# 0        Group C    Rural            110                            21
#
#    amount_spent  device
# 0        237.85  Mobile

# %%
#my_modeler.predict_regression(
#    df.loc[[0]]
#)

# %%
new_data_test= pd.DataFrame(
    data={
        'customer_group': ['Group C'],
        'location': ['Rural'],
        'n_days_member': [108],
        'n_avg_items_browsed_per_week': [19],
        'device': ['Mobile']
    }
)
new_data_test
# Out:
#   customer_group location  n_days_member  n_avg_items_browsed_per_week  device
# 0        Group C    Rural            108                            19  Mobile

# %%
# results = my_modeler.predict_regression(
#     new_data_test
# )
# results

# %% [markdown]
# ### Classification

# %%
# # Test results
# preds = my_modeler.classification()

# %% [markdown]
# ### Cluster

# %%
# # Test results
# cluster_labels = my_modeler.cluster()
# df['group_name'] = cluster_labels
