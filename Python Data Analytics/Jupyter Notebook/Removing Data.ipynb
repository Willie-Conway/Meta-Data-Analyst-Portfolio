# %%
import pandas as pd

# %%
df = pd.read_csv('csv/remove_customers.csv')

# %%
df.head()
# Out:
#                                           CustomerID  gender  SeniorCitizen  \
# 0  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...  Female              0
# 1  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    Male              0
# 2  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...  Female              1
# 3  4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...  Female              1
# 4  4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...  Female              1
#
#   Partner Dependents  Tenure PhoneService MultipleLines InternetService  \
# 0      No         No      58          Yes           Yes              No
# 1     Yes        Yes      64          Yes            No             DSL
# 2      No        Yes      11          Yes           Yes              No
# 3     Yes        Yes       3          Yes           Yes             DSL
# 4      No        Yes      40           No           Yes              No
#
# ...

# %%
df.drop(columns='1_column')
# Out:
#                                              CustomerID  gender  \
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...  Female
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    Male
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...  Female
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...  Female
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...  Female
# ...                                                 ...     ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...    Male
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...  Female
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...  Female
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...    Male
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...    Male
#
#       SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 0                 0      No         No      58          Yes           Yes
# ...

# %%
df
# Out:
#                                              CustomerID  gender  \
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...  Female
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    Male
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...  Female
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...  Female
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...  Female
# ...                                                 ...     ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...    Male
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...  Female
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...  Female
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...    Male
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...    Male
#
#       SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 0                 0      No         No      58          Yes           Yes
# ...

# %%
df_clean = df.drop(columns='1_column')

# %%
df_clean
# Out:
#                                              CustomerID  gender  \
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...  Female
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    Male
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...  Female
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...  Female
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...  Female
# ...                                                 ...     ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...    Male
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...  Female
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...  Female
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...    Male
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...    Male
#
#       SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 0                 0      No         No      58          Yes           Yes
# ...

# %%
df.drop('1_column', axis=1)
# Out:
#                                              CustomerID  gender  \
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...  Female
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    Male
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...  Female
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...  Female
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...  Female
# ...                                                 ...     ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...    Male
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...  Female
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...  Female
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...    Male
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...    Male
#
#       SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines  \
# 0                 0      No         No      58          Yes           Yes
# ...

# %%
df_clean = df_clean.drop(columns =['gender', 'Dependents'])
df_clean
# Out:
#                                              CustomerID  SeniorCitizen  \
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...              0
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...              0
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...              1
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...              1
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...              1
# ...                                                 ...            ...
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...              0
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...              0
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...              1
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...              0
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...              1
#
#      Partner  Tenure PhoneService MultipleLines InternetService  \
# ...

# %%
df_clean.drop(index=3826)
# Out:
#                                              CustomerID  SeniorCitizen  \
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...              0
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...              0
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...              1
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...              1
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...              1
# ...                                                 ...            ...
# 3821  8d6906944de869776836690859de9bb9ff8d82fd11b7c1...              1
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...              0
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...              0
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...              1
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...              0
#
#      Partner  Tenure PhoneService MultipleLines InternetService  \
# ...

# %%
df_clean.drop(3826, axis=0)
# Out:
#                                              CustomerID  SeniorCitizen  \
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...              0
# 1     6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...              0
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...              1
# 3     4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...              1
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...              1
# ...                                                 ...            ...
# 3821  8d6906944de869776836690859de9bb9ff8d82fd11b7c1...              1
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...              0
# 3823  08ff39839627d6e1619e05b005f41c51face303bfb6fcd...              0
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...              1
# 3825  32948fbafc29b36f18c4a96e5d1bd2789d2232f3f56a2a...              0
#
#      Partner  Tenure PhoneService MultipleLines InternetService  \
# ...

# %%
df_clean.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3822    False
# 3823    False
# 3824    False
# 3825    False
# 3826    False
# Length: 3827, dtype: bool

# %%
df_clean.duplicated(keep='last')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3822    False
# 3823    False
# 3824    False
# 3825    False
# 3826    False
# Length: 3827, dtype: bool

# %%
df_clean.duplicated(keep=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3822    False
# 3823    False
# 3824    False
# 3825    False
# 3826    False
# Length: 3827, dtype: bool

# %%
df_clean.duplicated(subset='CustomerID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3822    False
# 3823    False
# 3824    False
# 3825    False
# 3826    False
# Length: 3827, dtype: bool

# %%
not_duplicate = ~df_clean.duplicated(subset='CustomerID')

# %%
df_dedup = df_clean[not_duplicate]

# %%
df_no_null = df_dedup[(~df_dedup.InternetService.isna()) & (~df_dedup.MultipleLines.isna())]

# %%
not_dsl = df_no_null.InternetService != 'DSL'
df_final = df_no_null[not_dsl]

# %%
df_final
# Out:
#                                              CustomerID  SeniorCitizen  \
# 0     5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...              0
# 2     d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...              1
# 4     4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...              1
# 5     ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...              1
# 9     19581e27de7ced00ff1ce50b2047e7a567c76b1cbaebab...              0
# ...                                                 ...            ...
# 3818  f77030293f52196bb4655d18cf6f3472dfb04a856e0a0f...              0
# 3821  8d6906944de869776836690859de9bb9ff8d82fd11b7c1...              1
# 3822  71300a607803afff20dbf578af63c845836ef7495a4df1...              0
# 3824  03340dc42c4919ce6019ae44c24f3997ccd529f7af6f7f...              1
# 3826  61f1658abb2793093fd8a1afabc600dad20001526baa94...              1
#
#      Partner  Tenure PhoneService MultipleLines InternetService  \
# ...
